# %%
import csv
import pandas as pd
import numpy as np
df = pd.read_csv('3VAC1.csv')
df
# Out:
#      oper_status    status_detail poller_source          device_id  \
# 0        SUCCESS  Successful Scan           ACS  3c:04:61:fe:1e:81
# 1        SUCCESS  Successful Scan           ACS  58:19:f8:2a:ce:a7
# 2        SUCCESS  Successful Scan           ACS  a8:97:cd:41:0e:f1
# 3        SUCCESS  Successful Scan           ACS  b0:da:f9:3e:5d:c6
# 4        SUCCESS  Successful Scan           ACS  d4:04:cd:d6:f3:5d
# ...          ...              ...           ...                ...
# 1041     SUCCESS  Successful Scan           ACS  98:52:4a:07:80:ff
# 1042     SUCCESS  Successful Scan           ACS  98:f7:d7:b8:e6:f9
# 1043     SUCCESS  Successful Scan           ACS  08:a7:c0:a3:f0:ba
# 1044     SUCCESS  Successful Scan           ACS  a8:97:cd:40:37:a5
# 1045     SUCCESS  Successful Scan           ACS  7c:26:34:76:83:7a
#
#                  collection_time      span  bins     first       last  \
# 0     2021-12-31 14:17:24.315516  60000000   512  36000000  996000000
# ...

# %%
for i in range(len(df)):
    df['amplitudes'][i]= df['amplitudes'][i][1:len(df['amplitudes'][i])-2]
    df['amplitudes'][i] = np.array(df['amplitudes'][i].split(','))
df
# Out:
# <ipython-input-11-df68fd25635d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amplitudes'][i]= df['amplitudes'][i][1:len(df['amplitudes'][i])-2]
# <ipython-input-11-df68fd25635d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amplitudes'][i] = np.array(data.split(','))
#      oper_status    status_detail poller_source          device_id  \
# 0        SUCCESS  Successful Scan           ACS  3c:04:61:fe:1e:81
# 1        SUCCESS  Successful Scan           ACS  58:19:f8:2a:ce:a7
# 2        SUCCESS  Successful Scan           ACS  a8:97:cd:41:0e:f1
# ...

# %%
dataTypeSeries = df.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# oper_status        object
# status_detail      object
# poller_source      object
# device_id          object
# collection_time    object
# span                int64
# bins                int64
# first               int64
# last                int64
# amplitudes         object
# offset              int64
# partition           int64
# load_dt            object
# site_id             int64
# dtype: object

# %%
df['amplitudes'][0]
# Out:
# array(['-6262', ' -6033', ' -6128', ..., ' -7084', ' -6988', ' -687'],
#       dtype='<U6')

# %%
df.describe()
# Out:
#              span    bins       first         last        offset    partition  \
# count      1046.0  1046.0      1046.0       1046.0  1.046000e+03  1046.000000
# mean   60000000.0   512.0  36000000.0  996000000.0  2.476339e+07     1.937859
# std           0.0     0.0         0.0          0.0  1.860440e+04     1.450610
# min    60000000.0   512.0  36000000.0  996000000.0  2.472888e+07     0.000000
# 25%    60000000.0   512.0  36000000.0  996000000.0  2.474750e+07     1.000000
# 50%    60000000.0   512.0  36000000.0  996000000.0  2.476306e+07     2.000000
# 75%    60000000.0   512.0  36000000.0  996000000.0  2.477913e+07     3.000000
# max    60000000.0   512.0  36000000.0  996000000.0  2.479748e+07     4.000000
#
#        site_id
# count   1046.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0

# %%
import wave
data = df['amplitudes'][0]
#data = data[1:len(data)-2]
#data1 = np.array(data.split(','))
import matplotlib.pyplot as plt

#data1[data1 < 0] = abs(data1)
#power_db = 20 * log10(amp / amp_ref)
data = [float(i)/100 for i in data]
#data = [pow (10, float(i)/2000) for i in data]
data
# Out:
# [-62.62,
#  -60.33,
#  -61.28,
#  -64.34,
#  -64.24,
#  -62.54,
#  -62.92,
#  -61.56,
#  -60.85,
#  -61.12,
#  -61.53,
#  -61.39,
#  -62.52,
#  -63.81,
#  -63.85,
#  -60.8,
#  -63.37,
#  -62.32,
#  -63.86,
#  -64.79,
#  -61.06,
#  -60.72,
#  -61.97,
#  -62.9,
#  -64.47,
#  -62.94,
#  -66.47,
#  -64.4,
#  -62.72,
#  -61.4,
#  -62.64,
#  -65.16,
#  -62.84,
#  -62.18,
#  -64.81,
#  -63.29,
#  -64.48,
#  -70.75,
#  -65.81,
#  -63.12,
#  -62.98,
#  -62.7,
#  -62.95,
#  -62.51,
#  -62.91,
#  -63.67,
#  -64.74,
#  -63.17,
#  -64.81,
#  -62.75,
#  -62.26,
#  -65.23,
#  -63.31,
#  -64.9,
#  -63.74,
#  -64.05,
#  -63.3,
#  -61.38,
#  -61.58,
#  -60.76,
#  -62.06,
#  -61.81,
#  -61.44,
#  -60.74,
#  -65.23,
#  -62.5,
#  -63.67,
#  -63.99,
#  -63.66,
#  -63.39,
#  -64.14,
#  -63.86,
#  -62.75,
#  -63.53,
#  -64.0,
#  -66.02,
#  -65.24,
#  -64.6,
#  -63.48,
#  -64.65,
#  -64.96,
#  -63.44,
#  -64.17,
#  -66.8,
#  -67.64,
#  -66.52,
#  -65.3,
#  -65.37,
#  -67.8,
#  -67.49,
#  -65.42,
#  -64.12,
# ...

# %%
len(data)
x = np.array(np.arange(36,996,960/8704.))
x
# Out:
# array([ 36.        ,  36.11029412,  36.22058824, ..., 995.66911765,
#        995.77941176, 995.88970588])

# %%
import pylab
import matplotlib.pyplot as plt
fig = plt.figure()

plt.plot(x, data, color='blue', lw=2)


pylab.show()

# %%
import seaborn as sns
 
# use seaborn style
sns.set_theme()
plt.plot(data)
plt.show()
